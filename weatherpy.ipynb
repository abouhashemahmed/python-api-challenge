# %%
api_key = "def2e83bef5b828ede1e006a6dfebab6"

# %%
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime

# %%
counter = 0
rndlat=[]
rndlon=[]

while len(rndlat) < 750:
    lat = np.random.uniform(-90, 90)
    lon = np.random.uniform(-180,180)
    rndlat.append(lat)
    rndlon.append(lon)
    counter += 1
 

geo_df = pd.DataFrame ({"lat": rndlat, "lon":rndlon})
geo_df.head()
# Out:
#          lat         lon
# 0 -87.328414  168.173851
# 1 -75.125369   91.744845
# 2 -11.707763   82.627922
# 3  31.549940   94.339933
# 4   1.490223 -128.207180

# %%
city = []
country = []


for index, row in geo_df.iterrows():
    city_lat=(row["lat"])
    city_lon=(row["lon"])
    city_name = citipy.nearest_city(city_lat, city_lon).city_name
    country_code = citipy.nearest_city(city_lat, city_lon).country_code
    city.append(city_name)
    country.append(country_code)
    
city_df= pd.DataFrame ({"city": city, "country": country})
city_df.drop_duplicates(["city", "country"])
city_df.head()
# Out:
#         city country
# 0      bluff      nz
# 1  busselton      au
# 2  hithadhoo      mv
# 3      along      in
# 4     atuona      pf

# %%
weather_data=[]

# %%
base_url="http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="

for index, row in city_df.iterrows():
        city_q=row["city"]
        response = requests.get(query_url + city_q).json()
        record_counter=1
        try:
            temp=response["main"]["temp"]
            humid=response["main"]["humidity"]
            cloud=response["clouds"]["all"]
            wind=response["wind"]["speed"]
            city_lat=response["coord"]["lat"]
            city_name=response["name"]
            city_country=response["sys"]["country"]
            weather_data.append({"City": city_name, "Country": city_country, "Latitude": city_lat,
                                "Temperature (F)": temp, "Humidity (%)": humid, "Cloudiness (%)":cloud, "Wind Speed (MPH)": wind})
            print (f"Processing record #{record_counter} -- {city_q}")
            print (f'{base_url}appid=***masked***&units={units}&q={city_q}')
            print ("----------------------------------------------------------------")
            record_counter +=1
        except:
            print (f"Weather for {city_q} not found.")
            print ("----------------------------------------------------------------")
            continue
# Out:
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hithadhoo
# ----------------------------------------------------------------
# Processing record #1 -- along
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=along
# ----------------------------------------------------------------
# Processing record #1 -- atuona
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=atuona
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- lavras
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lavras
# ----------------------------------------------------------------
# Processing record #1 -- lalsot
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lalsot
# ----------------------------------------------------------------
# Processing record #1 -- norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=norman wells
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- port keats
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port keats
# ----------------------------------------------------------------
# Processing record #1 -- loding
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=loding
# ----------------------------------------------------------------
# Processing record #1 -- tautira
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tautira
# ----------------------------------------------------------------
# Processing record #1 -- kapit
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapit
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Processing record #1 -- talara
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=talara
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- wuwei
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=wuwei
# ----------------------------------------------------------------
# Weather for illoqqortoormiut not found.
# ----------------------------------------------------------------
# Processing record #1 -- lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lompoc
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Weather for amderma not found.
# ----------------------------------------------------------------
# Processing record #1 -- magway
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=magway
# ----------------------------------------------------------------
# Processing record #1 -- ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ilulissat
# ----------------------------------------------------------------
# Processing record #1 -- pochutla
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pochutla
# ----------------------------------------------------------------
# Processing record #1 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=provideniya
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=labuhan
# ----------------------------------------------------------------
# Processing record #1 -- victoria
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=victoria
# ----------------------------------------------------------------
# Processing record #1 -- husavik
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=husavik
# ----------------------------------------------------------------
# Processing record #1 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=provideniya
# ----------------------------------------------------------------
# Processing record #1 -- qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=qaanaaq
# ----------------------------------------------------------------
# Processing record #1 -- snezhnogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=snezhnogorsk
# ----------------------------------------------------------------
# Processing record #1 -- meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=meulaboh
# ----------------------------------------------------------------
# Processing record #1 -- tongliao
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tongliao
# ----------------------------------------------------------------
# Processing record #1 -- komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=komsomolskiy
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=arraial do cabo
# ----------------------------------------------------------------
# Processing record #1 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hermanus
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=chokurdakh
# ----------------------------------------------------------------
# Processing record #1 -- pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pangnirtung
# ----------------------------------------------------------------
# Processing record #1 -- manturovo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=manturovo
# ----------------------------------------------------------------
# Processing record #1 -- goundam
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=goundam
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- lithgow
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lithgow
# ----------------------------------------------------------------
# Processing record #1 -- monkey hill
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=monkey hill
# ----------------------------------------------------------------
# Processing record #1 -- georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=georgetown
# ----------------------------------------------------------------
# Processing record #1 -- banapur
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=banapur
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=grand gaube
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=anadyr
# ----------------------------------------------------------------
# Processing record #1 -- san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=san patricio
# ----------------------------------------------------------------
# Processing record #1 -- georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=georgetown
# ----------------------------------------------------------------
# Processing record #1 -- srikakulam
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=srikakulam
# ----------------------------------------------------------------
# Processing record #1 -- isangel
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=isangel
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=upernavik
# ----------------------------------------------------------------
# Processing record #1 -- arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=arraial do cabo
# ----------------------------------------------------------------
# Processing record #1 -- providencia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=providencia
# ----------------------------------------------------------------
# Processing record #1 -- ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ulladulla
# ----------------------------------------------------------------
# Processing record #1 -- fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=fortuna
# ----------------------------------------------------------------
# Processing record #1 -- aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=aklavik
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- el dorado
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=el dorado
# ----------------------------------------------------------------
# Processing record #1 -- narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=narsaq
# ----------------------------------------------------------------
# Processing record #1 -- hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hasaki
# ----------------------------------------------------------------
# Processing record #1 -- victoria
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=victoria
# ----------------------------------------------------------------
# Processing record #1 -- ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ostrovnoy
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=labuhan
# ----------------------------------------------------------------
# Processing record #1 -- bull savanna
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bull savanna
# ----------------------------------------------------------------
# Weather for bargal not found.
# ----------------------------------------------------------------
# Processing record #1 -- geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=geraldton
# ----------------------------------------------------------------
# Weather for belushya guba not found.
# ----------------------------------------------------------------
# Weather for mys shmidta not found.
# ----------------------------------------------------------------
# Processing record #1 -- minab
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=minab
# ----------------------------------------------------------------
# Processing record #1 -- hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hithadhoo
# ----------------------------------------------------------------
# Processing record #1 -- norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=norman wells
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=katsuura
# ----------------------------------------------------------------
# Weather for kegayli not found.
# ----------------------------------------------------------------
# Processing record #1 -- kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kulhudhuffushi
# ----------------------------------------------------------------
# Processing record #1 -- luau
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=luau
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- kushmurun
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kushmurun
# ----------------------------------------------------------------
# Processing record #1 -- beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=beringovskiy
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Processing record #1 -- sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sao filipe
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port alfred
# ----------------------------------------------------------------
# Processing record #1 -- torbay
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=torbay
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=caravelas
# ----------------------------------------------------------------
# Processing record #1 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# Processing record #1 -- meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=meulaboh
# ----------------------------------------------------------------
# Processing record #1 -- muros
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=muros
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nikolskoye
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- victoria
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=victoria
# ----------------------------------------------------------------
# Processing record #1 -- cesenatico
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cesenatico
# ----------------------------------------------------------------
# Processing record #1 -- amangarh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=amangarh
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- tocopilla
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tocopilla
# ----------------------------------------------------------------
# Processing record #1 -- cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cururupu
# ----------------------------------------------------------------
# Processing record #1 -- vung tau
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vung tau
# ----------------------------------------------------------------
# Processing record #1 -- joao camara
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=joao camara
# ----------------------------------------------------------------
# Processing record #1 -- saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saskylakh
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- barrow
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=barrow
# ----------------------------------------------------------------
# Processing record #1 -- east london
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=east london
# ----------------------------------------------------------------
# Processing record #1 -- santarem
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=santarem
# ----------------------------------------------------------------
# Processing record #1 -- severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=severo-kurilsk
# ----------------------------------------------------------------
# Processing record #1 -- srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=srednekolymsk
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=luderitz
# ----------------------------------------------------------------
# Processing record #1 -- montepuez
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=montepuez
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cap malheureux
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- bethel
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bethel
# ----------------------------------------------------------------
# Processing record #1 -- san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=san patricio
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=khatanga
# ----------------------------------------------------------------
# Processing record #1 -- krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=krasnoselkup
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tasiilaq
# ----------------------------------------------------------------
# Processing record #1 -- adrar
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=adrar
# ----------------------------------------------------------------
# Processing record #1 -- dikson
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=dikson
# ----------------------------------------------------------------
# Processing record #1 -- tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tiksi
# ----------------------------------------------------------------
# Processing record #1 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port alfred
# ----------------------------------------------------------------
# Processing record #1 -- liepaja
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=liepaja
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- ulverstone
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ulverstone
# ----------------------------------------------------------------
# Processing record #1 -- labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=labuhan
# ----------------------------------------------------------------
# Processing record #1 -- yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=yellowknife
# ----------------------------------------------------------------
# Processing record #1 -- sandpoint
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sandpoint
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=srednekolymsk
# ----------------------------------------------------------------
# Processing record #1 -- mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mitsamiouli
# ----------------------------------------------------------------
# Processing record #1 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hilo
# ----------------------------------------------------------------
# Processing record #1 -- ghanzi
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ghanzi
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mount gambier
# ----------------------------------------------------------------
# Processing record #1 -- torbay
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=torbay
# ----------------------------------------------------------------
# Processing record #1 -- sabha
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sabha
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-augustin
# ----------------------------------------------------------------
# Processing record #1 -- bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bambous virieux
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- colquiri
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=colquiri
# ----------------------------------------------------------------
# Processing record #1 -- poum
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=poum
# ----------------------------------------------------------------
# Processing record #1 -- timiryazevskoye
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=timiryazevskoye
# ----------------------------------------------------------------
# Processing record #1 -- mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mahebourg
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- lasa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lasa
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- avarua
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=avarua
# ----------------------------------------------------------------
# Processing record #1 -- atuona
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=atuona
# ----------------------------------------------------------------
# Processing record #1 -- touros
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=touros
# ----------------------------------------------------------------
# Processing record #1 -- chuy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=chuy
# ----------------------------------------------------------------
# Processing record #1 -- tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tuatapere
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Weather for illoqqortoormiut not found.
# ----------------------------------------------------------------
# Processing record #1 -- broome
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=broome
# ----------------------------------------------------------------
# Processing record #1 -- capreol
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=capreol
# ----------------------------------------------------------------
# Weather for viligili not found.
# ----------------------------------------------------------------
# Processing record #1 -- sur
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=sur
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=georgetown
# ----------------------------------------------------------------
# Processing record #1 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port alfred
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- airai
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=airai
# ----------------------------------------------------------------
# Processing record #1 -- hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hamilton
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Weather for illoqqortoormiut not found.
# ----------------------------------------------------------------
# Processing record #1 -- port augusta
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port augusta
# ----------------------------------------------------------------
# Processing record #1 -- chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=chokurdakh
# ----------------------------------------------------------------
# Processing record #1 -- huarmey
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=huarmey
# ----------------------------------------------------------------
# Processing record #1 -- bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bubaque
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- tingi
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tingi
# ----------------------------------------------------------------
# Processing record #1 -- nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nikolskoye
# ----------------------------------------------------------------
# Processing record #1 -- bethel
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bethel
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Weather for mys shmidta not found.
# ----------------------------------------------------------------
# Processing record #1 -- los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=los llanos de aridane
# ----------------------------------------------------------------
# Processing record #1 -- pevek
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pevek
# ----------------------------------------------------------------
# Processing record #1 -- castro
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=castro
# ----------------------------------------------------------------
# Processing record #1 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=provideniya
# ----------------------------------------------------------------
# Processing record #1 -- kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kaitangata
# ----------------------------------------------------------------
# Processing record #1 -- colares
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=colares
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=nanortalik
# ----------------------------------------------------------------
# Processing record #1 -- ljungby
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ljungby
# ----------------------------------------------------------------
# Processing record #1 -- alpena
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=alpena
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- karratha
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=karratha
# ----------------------------------------------------------------
# Processing record #1 -- ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ponta do sol
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=walvis bay
# ----------------------------------------------------------------
# Processing record #1 -- busselton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=busselton
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=carnarvon
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Weather for taolanaro not found.
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Weather for mys shmidta not found.
# ----------------------------------------------------------------
# Processing record #1 -- omsukchan
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=omsukchan
# ----------------------------------------------------------------
# Processing record #1 -- tura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tura
# ----------------------------------------------------------------
# Processing record #1 -- provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=provideniya
# ----------------------------------------------------------------
# Processing record #1 -- lata
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lata
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=san carlos de bariloche
# ----------------------------------------------------------------
# Processing record #1 -- atambua
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=atambua
# ----------------------------------------------------------------
# Processing record #1 -- duluth
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=duluth
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hamilton
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=qaanaaq
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=khatanga
# ----------------------------------------------------------------
# Processing record #1 -- arman
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=arman
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mugur-aksy
# ----------------------------------------------------------------
# Processing record #1 -- tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tuktoyaktuk
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- avarua
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=avarua
# ----------------------------------------------------------------
# Weather for sentyabrskiy not found.
# ----------------------------------------------------------------
# Processing record #1 -- kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kruisfontein
# ----------------------------------------------------------------
# Processing record #1 -- arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=arraial do cabo
# ----------------------------------------------------------------
# Processing record #1 -- saint george
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint george
# ----------------------------------------------------------------
# Processing record #1 -- tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tuktoyaktuk
# ----------------------------------------------------------------
# Processing record #1 -- dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=dunedin
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- opunake
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=opunake
# ----------------------------------------------------------------
# Processing record #1 -- fredonia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=fredonia
# ----------------------------------------------------------------
# Weather for belushya guba not found.
# ----------------------------------------------------------------
# Weather for karakendzha not found.
# ----------------------------------------------------------------
# Processing record #1 -- camacha
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=adamovka
# ----------------------------------------------------------------
# Processing record #1 -- vaini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=vaini
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bonavista
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- murgab
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=murgab
# ----------------------------------------------------------------
# Processing record #1 -- kincardine
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kincardine
# ----------------------------------------------------------------
# Processing record #1 -- narasannapeta
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=narasannapeta
# ----------------------------------------------------------------
# Weather for amderma not found.
# ----------------------------------------------------------------
# Processing record #1 -- la ceja
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=la ceja
# ----------------------------------------------------------------
# Weather for illoqqortoormiut not found.
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- tari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tari
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- ayia galini
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ayia galini
# ----------------------------------------------------------------
# Processing record #1 -- hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hithadhoo
# ----------------------------------------------------------------
# Processing record #1 -- mecca
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mecca
# ----------------------------------------------------------------
# Weather for alotau not found.
# ----------------------------------------------------------------
# Processing record #1 -- saint george
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint george
# ----------------------------------------------------------------
# Processing record #1 -- port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port lincoln
# ----------------------------------------------------------------
# Processing record #1 -- lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lagoa
# ----------------------------------------------------------------
# Processing record #1 -- ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ribeira grande
# ----------------------------------------------------------------
# Processing record #1 -- tautira
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tautira
# ----------------------------------------------------------------
# Processing record #1 -- mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mahebourg
# ----------------------------------------------------------------
# Processing record #1 -- la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=la ronge
# ----------------------------------------------------------------
# Processing record #1 -- bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bredasdorp
# ----------------------------------------------------------------
# Processing record #1 -- heiligenhafen
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=heiligenhafen
# ----------------------------------------------------------------
# Processing record #1 -- jalu
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jalu
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- bluff
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bluff
# ----------------------------------------------------------------
# Weather for grand river south east not found.
# ----------------------------------------------------------------
# Processing record #1 -- hilo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hilo
# ----------------------------------------------------------------
# Processing record #1 -- saint george
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint george
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=verkhoyansk
# ----------------------------------------------------------------
# Processing record #1 -- hobart
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hobart
# ----------------------------------------------------------------
# Processing record #1 -- skibbereen
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=skibbereen
# ----------------------------------------------------------------
# Processing record #1 -- pevek
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pevek
# ----------------------------------------------------------------
# Processing record #1 -- usinsk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=usinsk
# ----------------------------------------------------------------
# Processing record #1 -- butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=butaritari
# ----------------------------------------------------------------
# Processing record #1 -- shishou
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=shishou
# ----------------------------------------------------------------
# Processing record #1 -- cape town
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cape town
# ----------------------------------------------------------------
# Processing record #1 -- kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kapaa
# ----------------------------------------------------------------
# Processing record #1 -- mercedes
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mercedes
# ----------------------------------------------------------------
# Processing record #1 -- lima
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=lima
# ----------------------------------------------------------------
# Weather for illoqqortoormiut not found.
# ----------------------------------------------------------------
# Processing record #1 -- tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tecoanapa
# ----------------------------------------------------------------
# Processing record #1 -- moussoro
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=moussoro
# ----------------------------------------------------------------
# Weather for grand river south east not found.
# ----------------------------------------------------------------
# Processing record #1 -- mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mar del plata
# ----------------------------------------------------------------
# Processing record #1 -- hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hithadhoo
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto ayora
# ----------------------------------------------------------------
# Processing record #1 -- tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tuatapere
# ----------------------------------------------------------------
# Processing record #1 -- trelew
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=trelew
# ----------------------------------------------------------------
# Processing record #1 -- praia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=praia
# ----------------------------------------------------------------
# Processing record #1 -- ancud
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ancud
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=punta arenas
# ----------------------------------------------------------------
# Processing record #1 -- half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=half moon bay
# ----------------------------------------------------------------
# Processing record #1 -- puerto colombia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=puerto colombia
# ----------------------------------------------------------------
# Processing record #1 -- pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=pangnirtung
# ----------------------------------------------------------------
# Processing record #1 -- arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=arraial do cabo
# ----------------------------------------------------------------
# Processing record #1 -- hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hermanus
# ----------------------------------------------------------------
# Processing record #1 -- cheyenne
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=cheyenne
# ----------------------------------------------------------------
# Processing record #1 -- temyasovo
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=temyasovo
# ----------------------------------------------------------------
# Weather for saleaula not found.
# ----------------------------------------------------------------
# Processing record #1 -- new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=new norfolk
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=jamestown
# ----------------------------------------------------------------
# Processing record #1 -- ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=ushuaia
# ----------------------------------------------------------------
# Processing record #1 -- tripoli
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=tripoli
# ----------------------------------------------------------------
# Processing record #1 -- albany
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=albany
# ----------------------------------------------------------------
# Processing record #1 -- rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=rikitea
# ----------------------------------------------------------------
# Processing record #1 -- hasanabad
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=hasanabad
# ----------------------------------------------------------------
# Processing record #1 -- swan hill
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=swan hill
# ----------------------------------------------------------------
# Processing record #1 -- port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=port alfred
# ----------------------------------------------------------------
# Processing record #1 -- konotop
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=konotop
# ----------------------------------------------------------------
# Processing record #1 -- qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=qaanaaq
# ----------------------------------------------------------------
# Processing record #1 -- saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=saint-georges
# ----------------------------------------------------------------
# Processing record #1 -- mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mar del plata
# ----------------------------------------------------------------
# Processing record #1 -- geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=geraldton
# ----------------------------------------------------------------
# Processing record #1 -- mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mount gambier
# ----------------------------------------------------------------
# Processing record #1 -- mataura
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=mataura
# ----------------------------------------------------------------
# Processing record #1 -- kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=kavaratti
# ----------------------------------------------------------------
# Processing record #1 -- bara
# http://api.openweathermap.org/data/2.5/weather?appid=***masked***&units=imperial&q=bara
# ----------------------------------------------------------------

# %%
print (len(weather_data))
# Out:
# 692

# %%
weather_df=pd.DataFrame(weather_data)
weather_df=weather_df[["City", "Country","Latitude","Temperature (F)", "Humidity (%)", "Cloudiness (%)", "Wind Speed (MPH)"]]
weather_df.head()
# Out:
#         City Country  Latitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0      Bluff      NZ    -46.60            84.43            36             100
# 1  Busselton      AU    -33.65            78.76            33               0
# 2  Hithadhoo      MV     -0.60            84.47            78              18
# 3      Along      IN     28.17            53.40            72              81
# 4     Atuona      PF     -9.80            81.25            75               1
#
#    Wind Speed (MPH)
# 0              5.41
# 1              7.36
# 2             11.63
# 3              1.57
# 4             11.72

# %%
date = datetime.now()
date = date.strftime("%m-%d-%Y")

plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Temperature ($^\circ$F)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("temp.png")
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Humidity (%)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("humidity.png")
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness (%)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Cloudiness (%)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("clouds.png")
plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed (MPH)"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Wind Speed (MPH)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("wind.png")
plt.show()
